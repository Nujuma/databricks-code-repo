# %%
df1 = spark.read.csv(
    "/Volumes/workspace/default/volumewd36/custs",header=True).toDF("Id","fname","lname","age","Profession")
df1.write.mode("overwrite").saveAsTable("customer1")
print("Customer table created")

# %%
/Volumes/workspace/default/volumewd36/custs
